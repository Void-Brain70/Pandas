# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Pandas/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# df = pd.read_csv("/content/Temp_and_rain.csv")
df = pd.read_csv("/content/nyc_weather.csv");
df
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 0    1/1/2016           38        23  ...           5       NaN             281
# 1    1/2/2016           36        18  ...           3       NaN             275
# 2    1/3/2016           40        21  ...           1       NaN             277
# 3    1/4/2016           25         9  ...           3       NaN             345
# 4    1/5/2016           20        -3  ...           0       NaN             333
# 5    1/6/2016           33         4  ...           0       NaN             259
# 6    1/7/2016           39        11  ...           3       NaN             293
# 7    1/8/2016           39        29  ...           8       NaN              79
# 8    1/9/2016           44        38  ...           8      Rain              76
# 9   1/10/2016           50        46  ...           7      Rain             109
# 10  1/11/2016           33         8  ...           1       NaN             289
# ...

# %%
# df["Temperature"].max()
# Out:
# 50

# %%
# df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
# df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# Process of cleaning messy data is called data munging or data wrangling

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903
